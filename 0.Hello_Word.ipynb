# %% [markdown]
# <a href="https://colab.research.google.com/github/bpriantti/Python_Fundamentos/blob/main/0.Hello_Word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fundamentos de Python - Hello Word.
# ____
#
# __Objetivo:__
#
# O presente notebook visa abordar de forma auto-explicativa e orientada os principais topicos de programacao em python referentes a __Hello Word__, sendo assim um guia para a programacao na linguagem servindo tambem como repostorio para esclarecimento de duvidas durante o desenvolvimento.
#
# __Topicos:__
# 1. Definicao.
# 1. Declarando Variaveis.
# 1. Tipos Nativos de Variaveis.
# 1. Convertendo Tipos de Variaveis.
#
# __Autor:__
#    - Bruno Priantti.
#
# __Contato:__
#   - b.priantti@outlook.com
#
# __Encontre-me:__
#    -  https://www.linkedin.com/in/bpriantti/
#    -  https://github.com/bpriantti
#    -  https://www.instagram.com/brunopriantti/
#
# ___

# %% [markdown]
# ## Hello Word:
#
# O primeiro passo de toda linguagem de programacao é o Hello Word, para isso utilizamos a funcao __print()__ que mostra coisas na tela

# %%
#Hello Word
print('Hello Word')
# Out:
# Hello Word

# %% [markdown]
# ~~~
# Podemos utiliziar ' ' (aspas simples)
# Podemos utiliziar " " (aspas duplas)
#
#  '\n' Pular Linha.
#  '#' para comentar algo.
# ~~~

# %%
#utilize para mostrar coisas na comand line.
print('Qualquer Coisa')

#Em Programacao palavras sao chamadas de strings no python nao é diferente.
# Out:
# Qualquer Coisa

# %%
#Utilize a funcao input para escrever dados diretamente do console.
input('Digite uma frase aqui:')
# Out:
# Digite uma frase aqui:Bruno Priantti
# 'Bruno Priantti'

# %%
#Para Mostrar na Tela
print(input('Digite uma frase aqui:'))
# Out:
# Digite uma frase aqui:Bruno Priantti
# Bruno Priantti

# %%
#obs a saida sempre sera uma string.
